# %%
from openai import OpenAI

# สร้าง client
client = OpenAI(api_key="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")

# เนื้อหา 5 หัวข้อฟิสิกส์
content = """
1. แรงเสียดทาน  
แรงเสียดทานคือแรงที่ต้านการเคลื่อนที่ของวัตถุ เมื่อวัตถุเคลื่อนที่หรือต้องการเคลื่อนที่บนพื้นผิวหนึ่ง แรงเสียดทานจะเกิดขึ้นในทิศทางตรงข้ามกับการเคลื่อนที่ ซึ่งส่งผลให้วัตถุเคลื่อนที่ช้าลงหรือหยุดเคลื่อนที่ในที่สุด แรงเสียดทานเกิดจากลักษณะของพื้นผิวที่ขรุขระและการยึดเหนี่ยวระหว่างโมเลกุลของวัตถุกับพื้นผิว แรงเสียดทานสามารถจำแนกได้เป็นหลายประเภท เช่น แรงเสียดทานสถิต (เกิดขึ้นเมื่อวัตถุยังไม่เริ่มเคลื่อนที่) และแรงเสียดทานจลน์ (เกิดขึ้นระหว่างที่วัตถุกำลังเคลื่อนที่) ขนาดของแรงเสียดทานขึ้นอยู่กับน้ำหนักของวัตถุและลักษณะของพื้นผิว ยิ่งพื้นผิวหยาบมากเท่าไร แรงเสียดทานก็จะยิ่งมากขึ้น

2. แรงลัพธ์  
แรงลัพธ์คือแรงรวมที่เกิดจากแรงหลายแรงกระทำต่อวัตถุพร้อมกัน แรงลัพธ์จะเป็นตัวบอกว่าวัตถุจะเคลื่อนที่หรือไม่ และเคลื่อนที่ไปทางไหน ถ้าแรงลัพธ์ = 0 แสดงว่าวัตถุอยู่ในสภาพสมดุล คืออยู่นิ่งหรือเคลื่อนที่ด้วยความเร็วคงที่ ถ้าแรงลัพธ์ ≠ 0 วัตถุจะเปลี่ยนการเคลื่อนที่ เช่น เร่งความเร็ว ชะลอ หรือเปลี่ยนทิศทาง

3. พลังงานไฟฟ้า  
พลังงานไฟฟ้าคือพลังงานที่ได้จากการเคลื่อนที่ของอิเล็กตรอนในวงจรไฟฟ้า อุปกรณ์ไฟฟ้าต่าง ๆ เช่น หลอดไฟ พัดลม โทรศัพท์มือถือ ล้วนแปลงพลังงานไฟฟ้าเป็นพลังงานรูปอื่น เช่น แสง เสียง หรือพลังงานกล หน่วยของพลังงานไฟฟ้าในระบบสากลคือ “จูล” (J) หรืออาจวัดเป็นวัตต์-ชั่วโมง (Wh) ได้เช่นกัน พลังงานไฟฟ้าเกิดได้จากแหล่งพลังงานหลายชนิด เช่น ถ่านหิน น้ำ ลม หรือแสงอาทิตย์

4. เสียงและคลื่นเสียง  
เสียงเกิดจากการสั่นของวัตถุที่ทำให้อนุภาคของอากาศเกิดการสั่นตาม คลื่นเสียงเป็นคลื่นตามยาวที่ต้องใช้ตัวกลางในการเคลื่อนที่ เช่น อากาศ น้ำ หรือของแข็ง ความถี่ของคลื่นเสียงมีผลต่อระดับเสียง เสียงที่มนุษย์ได้ยินมีความถี่ระหว่าง 20 Hz ถึง 20,000 Hz เสียงที่ต่ำกว่าหรือสูงกว่านี้เรียกว่า อินฟราซาวด์ และอัลตราซาวด์ ตามลำดับ ความดังของเสียงขึ้นอยู่กับแอมพลิจูดของคลื่น

5. กฎการเคลื่อนที่ของนิวตัน  
เซอร์ไอแซก นิวตันเสนอว่าการเคลื่อนที่ของวัตถุสามารถอธิบายได้ด้วยกฎ 3 ข้อ:
- กฎข้อที่ 1 (กฎความเฉื่อย): วัตถุจะอยู่นิ่งหรือเคลื่อนที่ด้วยความเร็วคงที่ ถ้าไม่มีแรงมากระทำ
- กฎข้อที่ 2: F = ma → แรงลัพธ์ที่กระทำต่อวัตถุเท่ากับมวลคูณกับความเร่ง
- กฎข้อที่ 3: เมื่อมีแรงกระทำ จะมีแรงต้านกลับที่มีขนาดเท่ากันแต่ทิศตรงกัน
"""


# รวมเข้า prompt
prompt = f"""
คุณเป็น AI ครูฟิสิกส์ไทยระดับมัธยมต้น ให้อธิบายสรุปเนื้อหา และสร้างแบบทดสอบแบบปรนัยจากเนื้อหาด้านล่างนี้ โดยให้ผลลัพธ์อยู่ในรูปแบบนี้:

Summary:
[สรุปเนื้อหา 2-3 บรรทัดแบบเข้าใจง่าย]

Multiple Choice Questions:
**สร้างแบบทดสอบปรนัยจำนวน 10 ข้อ** โดยมี format ตามนี้

1. [คำถาม]
A. ...
B. ...
C. ...
D. ...
คำตอบที่ถูกต้อง: ข้อ...
คำอธิบาย: [อธิบายเหตุผลว่าทำไมข้อนี้ถึงถูก]

(ทำแบบเดียวกันจนครบ 10 ข้อ)

เนื้อหา:
{content}
"""

# เรียก GPT-4o
response = client.chat.completions.create(
    model="gpt-4o",
    messages=[{"role": "user", "content": prompt}],
    temperature=0.3,
    max_tokens=2048
)

# แสดงผล
print(response.choices[0].message.content)
# Out:
# Summary:
# แรงเสียดทานเป็นแรงที่ต้านการเคลื่อนที่ของวัตถุและมีหลายประเภท เช่น แรงเสียดทานสถิตและจลน์ แรงลัพธ์คือแรงรวมที่บอกการเคลื่อนที่ของวัตถุ พลังงานไฟฟ้าเกิดจากการเคลื่อนที่ของอิเล็กตรอนและแปลงเป็นพลังงานรูปอื่น เสียงเกิดจากการสั่นของวัตถุและเคลื่อนที่เป็นคลื่นตามยาว กฎการเคลื่อนที่ของนิวตันอธิบายการเคลื่อนที่ของวัตถุด้วยกฎ 3 ข้อ
#
# Multiple Choice Questions:
#
# 1. แรงเสียดทานเกิดจากอะไร?
# A. การเคลื่อนที่ของอิเล็กตรอน
# B. การยึดเหนี่ยวระหว่างโมเลกุลของวัตถุกับพื้นผิว
# C. การสั่นของวัตถุ
# D. การรวมกันของแรงหลายแรง
# คำตอบที่ถูกต้อง: ข้อ B
# คำอธิบาย: แรงเสียดทานเกิดจากการยึดเหนี่ยวระหว่างโมเลกุลของวัตถุกับพื้นผิวและลักษณะของพื้นผิวที่ขรุขระ
#
# 2. แรงลัพธ์มีค่าเท่าใดเมื่อวัตถุอยู่ในสภาพสมดุล?
# A. มากกว่า 0
# B. น้อยกว่า 0
# C. เท่ากับ 0
# D. ไม่แน่นอน
# คำตอบที่ถูกต้อง: ข้อ C
# คำอธิบาย: เมื่อแรงลัพธ์ = 0 วัตถุจะอยู่ในสภาพสมดุล คืออยู่นิ่งหรือเคลื่อนที่ด้วยความเร็วคงที่
#
# 3. พลังงานไฟฟ้าแปลงเป็นพลังงานรูปใดได้บ้าง?
# A. แสง
# B. เสียง
# C. พลังงานกล
# D. ถูกทุกข้อ
# ...

# %%
# !pip3 uninstall openai -y
# Out:
# Found existing installation: openai 0.28.0
# Uninstalling openai-0.28.0:
#   Successfully uninstalled openai-0.28.0

# %%
# !pip3 install --upgrade openai
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#   Using cached openai-1.86.0-py3-none-any.whl (730 kB)
# ...
# WARNING: You are using pip version 21.2.4; however, version 25.1.1 is available.
# You should consider upgrading via the '/Library/Developer/CommandLineTools/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
from openai import OpenAI

client = OpenAI(api_key="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")

models = client.models.list()

for m in models.data:
    print(m.id)
# Out:
# text-embedding-ada-002
# whisper-1
# gpt-3.5-turbo
# tts-1
# gpt-3.5-turbo-16k
# davinci-002
# babbage-002
# gpt-3.5-turbo-instruct
# gpt-3.5-turbo-instruct-0914
# dall-e-3
# dall-e-2
# gpt-3.5-turbo-1106
# tts-1-hd
# tts-1-1106
# tts-1-hd-1106
# text-embedding-3-small
# text-embedding-3-large
# gpt-3.5-turbo-0125
# gpt-4o
# gpt-4o-2024-05-13
# gpt-4o-mini-2024-07-18
# gpt-4o-mini
# gpt-4o-2024-08-06
# o1-preview-2024-09-12
# o1-preview
# o1-mini-2024-09-12
# o1-mini
# gpt-4o-audio-preview-2024-10-01
# gpt-4o-audio-preview
# omni-moderation-latest
# omni-moderation-2024-09-26
# gpt-4o-mini-audio-preview-2024-12-17
# gpt-4o-mini-audio-preview
# gpt-4o-2024-11-20
# gpt-4.5-preview
# gpt-4.5-preview-2025-02-27
# gpt-4o-search-preview-2025-03-11
# gpt-4o-search-preview
# gpt-4o-mini-search-preview-2025-03-11
# gpt-4o-mini-search-preview
# gpt-4o-transcribe
# gpt-4o-mini-transcribe
# gpt-4o-mini-tts
# gpt-4.1-2025-04-14
# gpt-4.1
# gpt-4.1-mini-2025-04-14
# gpt-4.1-mini
# ...
